# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('mnist_train.csv')
train = pd.DataFrame(train)

test = pd.read_csv('mnist_test.csv')
test = pd.DataFrame(test)

x_train = pd.read_csv('x_train.csv')
X_train = pd.DataFrame(x_train)

y_train = pd.read_csv('y_train.csv')
Y_train = pd.DataFrame(y_train)

X_train = X_train.values
Y_train = Y_train.values

# %%
X_train.shape
# Out:
# (60000, 784)

# %%
X_train = X_train.T
X_train.shape
# Out:
# (784, 60000)

# %%
plt.imshow(X_train[:, 0].reshape(28, 28), cmap='Greys')
plt.show()

# %%
images_0 = X_train[:, :5922]

# %%
from numpy.linalg import svd

U,S,V = svd(images_0)

# %%
#Original space of (784, 60000) dimentions
plt.figure(figsize=(25, 10))

for i in range(10):
    plt.subplot(2, 5, i+1)
    plt.imshow(images_0[:, i].reshape(28, 28), cmap='Greys')

plt.show()

# %%
#Eigenspace of (784, 784) dimentions
plt.figure(figsize=(25, 10))

for i in range(10):
    plt.subplot(2, 5, i+1)
    plt.imshow(U[:, i].reshape(28, 28), cmap='Greys')

plt.show()

# %%
x_test = pd.read_csv('x_test.csv')
X_test = pd.DataFrame(x_test)

X_test = X_test.values

# %%
X_test = X_test.T
X_test.shape
# Out:
# (784, 10000)

# %%
plt.figure(figsize=(20, 20))

plt.subplot(4, 4, 1)
plt.imshow(X_test[:, 3].reshape(28, 28), cmap='Greys')
plt.title('Original Img')

plt.subplot(4, 4, 2)
U_r = U[:, :5]
test_image = X_test[:, 3].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 5')

plt.subplot(4, 4, 3)
U_r = U[:, :10]
test_image = X_test[:, 3].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 10')

plt.subplot(4, 4, 4)
U_r = U[:, :25]
test_image = X_test[:, 3].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 25')

plt.subplot(4, 4, 5)
U_r = U[:, :50]
test_image = X_test[:, 3].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 50')

plt.subplot(4, 4, 6)
U_r = U[:, :100]
test_image = X_test[:, 3].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 100')

plt.subplot(4, 4, 7)
U_r = U[:, :150]
test_image = X_test[:, 3].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 150')

plt.subplot(4, 4, 8)
U_r = U[:, :200]
test_image = X_test[:, 3].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 200')

plt.subplot(4, 4, 9)
U_r = U[:, :300]
test_image = X_test[:, 3].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 300')

plt.subplot(4, 4, 10)
U_r = U[:, :400]
test_image = X_test[:, 3].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 400')

plt.subplot(4, 4, 11)
U_r = U[:, :500]
test_image = X_test[:, 3].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 500')

plt.subplot(4, 4, 12)
U_r = U[:, :600]
test_image = X_test[:, 3].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 600')

plt.show()

# %%
percentage_var_explained = S / np.sum(S)
cum_var_explained = np.cumsum(percentage_var_explained)

plt.plot(cum_var_explained, linewidth=2)
plt.xlabel('No of eigenimages')
plt.ylabel('variance')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20, 20))

plt.subplot(4, 4, 1)
plt.imshow(X_test[:, 1].reshape(28, 28), cmap='Greys')
plt.title('Original Img')

plt.subplot(4, 4, 2)
U_r = U[:, :5]
test_image = X_test[:, 1].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 5')

plt.subplot(4, 4, 3)
U_r = U[:, :10]
test_image = X_test[:, 1].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 10')

plt.subplot(4, 4, 4)
U_r = U[:, :25]
test_image = X_test[:, 1].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 25')
S
plt.subplot(4, 4, 5)
U_r = U[:, :50]
test_image = X_test[:, 1].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 50')

plt.subplot(4, 4, 6)
U_r = U[:, :100]
test_image = X_test[:, 1].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 100')

plt.subplot(4, 4, 7)
U_r = U[:, :150]
test_image = X_test[:, 1].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 150')

plt.subplot(4, 4, 8)
U_r = U[:, :200]
test_image = X_test[:, 1].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 200')

plt.subplot(4, 4, 9)
U_r = U[:, :300]
test_image = X_test[:, 1].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 300')

plt.subplot(4, 4, 10)
U_r = U[:, :400]
test_image = X_test[:, 1].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 400')

plt.subplot(4, 4, 11)
U_r = U[:, :500]
test_image = X_test[:, 1].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 500')

plt.subplot(4, 4, 12)
U_r = U[:, :600]
test_image = X_test[:, 1].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 600')

plt.subplot(4, 4, 13)
U_r = U[:, :700]
test_image = X_test[:, 1].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 700')

plt.show()

# %%
plt.imshow(X_test[:, 2].reshape(28, 28), cmap='Greys')
plt.show()

# %%
#Image in the subspace - alpha space U * test_image - projection of the test image on eigen vectors
#Encoding the Image

test_image = X_test[:, 2].reshape(-1, 1)
image = np.dot(U, test_image)
plt.imshow(image.reshape(28, 28), cmap='Greys')
plt.show()

# %%
#Reconstructing the Image
#Decoding the Image from the Alpha space
#image: Image in the alpha (lower dimentional space) space

reconstructed_image = np.dot(U.T, image)
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.show()

# %%
plt.figure(figsize=(20, 20))

plt.subplot(4, 4, 1)
plt.imshow(X_test[:, 2].reshape(28, 28), cmap='Greys')
plt.title('Original Img')

plt.subplot(4, 4, 2)
U_r = U[:, :5]
test_image = X_test[:, 2].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(X_test[:, 2].reshape(28, 28) - reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 5')

plt.subplot(4, 4, 3)
U_r = U[:, :10]
test_image = X_test[:, 2].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(X_test[:, 2].reshape(28, 28) - reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 10')

plt.subplot(4, 4, 4)
U_r = U[:, :25]
test_image = X_test[:, 2].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(X_test[:, 2].reshape(28, 28) - reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 25')

plt.subplot(4, 4, 5)
U_r = U[:, :50]
test_image = X_test[:, 2].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(X_test[:, 2].reshape(28, 28) - reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 50')

plt.subplot(4, 4, 6)
U_r = U[:, :100]
test_image = X_test[:, 2].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(X_test[:, 2].reshape(28, 28) - reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 100')

plt.subplot(4, 4, 7)
U_r = U[:, :150]
test_image = X_test[:, 2].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(X_test[:, 2].reshape(28, 28) - reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 150')

plt.subplot(4, 4, 8)
U_r = U[:, :200]
test_image = X_test[:, 2].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(X_test[:, 2].reshape(28, 28) - reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 200')

plt.subplot(4, 4, 9)
U_r = U[:, :300]
test_image = X_test[:, 2].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(X_test[:, 2].reshape(28, 28) - reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 300')

plt.subplot(4, 4, 10)
U_r = U[:, :400]
test_image = X_test[:, 2].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(X_test[:, 2].reshape(28, 28) - reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 400')

plt.subplot(4, 4, 11)
U_r = U[:, :500]
test_image = X_test[:, 2].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(X_test[:, 2].reshape(28, 28) - reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 500')

plt.subplot(4, 4, 12)
U_r = U[:, :600]
test_image = X_test[:, 2].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(X_test[:, 2].reshape(28, 28) - reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 600')

plt.subplot(4, 4, 13)
U_r = U[:, :700]
test_image = X_test[:, 2].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(X_test[:, 2].reshape(28, 28) - reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 700')

plt.show()

# %%
#Structural Similarity Index (SSIM)

from skimage.measure import compare_ssim

SSIM = []

plt.figure(figsize=(20, 20))

plt.subplot(4, 4, 1)
plt.imshow(X_test[:, 2].reshape(28, 28), cmap='Greys')
plt.title('Original Img')

plt.subplot(4, 4, 2)
U_r = U[:, :5]
test_image = X_test[:, 2].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
(score, diff) = compare_ssim(X_test[:, 2].reshape(28, 28) / 255, reconstructed_image.reshape(28, 28)/ 255, full=True)
SSIM.append(score)
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages:5 ' + 'SSIM: ' + str("{:.2f}".format(score)))

plt.subplot(4, 4, 3)
U_r = U[:, :10]
test_image = X_test[:, 2].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
(score, diff) = compare_ssim(X_test[:, 2].reshape(28, 28) / 255, reconstructed_image.reshape(28, 28)/ 255, full=True)
SSIM.append(score)
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages:10 ' + 'SSIM: ' + str("{:.2f}".format(score)))

plt.subplot(4, 4, 4)
U_r = U[:, :25]
test_image = X_test[:, 2].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
(score, diff) = compare_ssim(X_test[:, 2].reshape(28, 28) / 255, reconstructed_image.reshape(28, 28)/ 255, full=True)
SSIM.append(score)
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages:25 ' + 'SSIM: ' + str("{:.2f}".format(score)))

plt.subplot(4, 4, 5)
U_r = U[:, :50]
test_image = X_test[:, 2].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
(score, diff) = compare_ssim(X_test[:, 2].reshape(28, 28) / 255, reconstructed_image.reshape(28, 28)/ 255, full=True)
SSIM.append(score)
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages:50 ' + 'SSIM: ' + str("{:.2f}".format(score)))

plt.subplot(4, 4, 6)
U_r = U[:, :100]
test_image = X_test[:, 2].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
(score, diff) = compare_ssim(X_test[:, 2].reshape(28, 28) / 255, reconstructed_image.reshape(28, 28)/ 255, full=True)
SSIM.append(score)
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages:100 ' + 'SSIM: ' + str("{:.2f}".format(score)))

plt.subplot(4, 4, 7)
U_r = U[:, :150]
test_image = X_test[:, 2].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
(score, diff) = compare_ssim(X_test[:, 2].reshape(28, 28) / 255, reconstructed_image.reshape(28, 28)/ 255, full=True)
SSIM.append(score)
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages:150 ' + 'SSIM: ' + str("{:.2f}".format(score)))

plt.subplot(4, 4, 8)
U_r = U[:, :200]
test_image = X_test[:, 2].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
(score, diff) = compare_ssim(X_test[:, 2].reshape(28, 28) / 255, reconstructed_image.reshape(28, 28)/ 255, full=True)
SSIM.append(score)
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages:200 ' + 'SSIM: ' + str("{:.2f}".format(score)))

plt.subplot(4, 4, 9)
U_r = U[:, :300]
test_image = X_test[:, 2].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
(score, diff) = compare_ssim(X_test[:, 2].reshape(28, 28) / 255, reconstructed_image.reshape(28, 28)/ 255, full=True)
SSIM.append(score)
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages:300 ' + 'SSIM: ' + str("{:.2f}".format(score)))

plt.subplot(4, 4, 10)
U_r = U[:, :400]
test_image = X_test[:, 2].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
(score, diff) = compare_ssim(X_test[:, 2].reshape(28, 28) / 255, reconstructed_image.reshape(28, 28)/ 255, full=True)
SSIM.append(score)
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages:400 ' + 'SSIM: ' + str("{:.2f}".format(score)))

plt.subplot(4, 4, 11)
U_r = U[:, :500]
test_image = X_test[:, 2].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
(score, diff) = compare_ssim(X_test[:, 2].reshape(28, 28) / 255, reconstructed_image.reshape(28, 28)/ 255, full=True)
SSIM.append(score)
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages:500 ' + 'SSIM: ' + str("{:.2f}".format(score)))

plt.subplot(4, 4, 12)
U_r = U[:, :600]
test_image = X_test[:, 2].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
(score, diff) = compare_ssim(X_test[:, 2].reshape(28, 28) / 255, reconstructed_image.reshape(28, 28)/ 255, full=True)
SSIM.append(score)
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages:600 ' + 'SSIM: ' + str("{:.2f}".format(score)))

plt.subplot(4, 4, 13)
U_r = U[:, :700]
test_image = X_test[:, 2].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
(score, diff) = compare_ssim(X_test[:, 2].reshape(28, 28) / 255, reconstructed_image.reshape(28, 28)/ 255, full=True)
SSIM.append(score)
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages:700 ' + 'SSIM: ' + str("{:.2f}".format(score)))

plt.show()

# %%
x = [5, 10, 25, 50, 100, 150, 200, 300, 400, 500, 600, 700]

plt.plot(np.asarray(x).reshape(-1, 1), np.asarray(SSIM).reshape(-1, 1))
plt.xlabel('Eigenimages')
plt.ylabel('SSIM')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20, 20))

plt.subplot(4, 4, 1)
plt.imshow(X_test[:, 50].reshape(28, 28), cmap='Greys')
plt.title('Original Img')

plt.subplot(4, 4, 2)
U_r = U[:, :5]
test_image = X_test[:, 50].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 5')

plt.subplot(4, 4, 3)
U_r = U[:, :10]
test_image = X_test[:, 50].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 10')

plt.subplot(4, 4, 4)
U_r = U[:, :25]
test_image = X_test[:, 50].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 25')
S
plt.subplot(4, 4, 5)
U_r = U[:, :50]
test_image = X_test[:, 50].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 50')

plt.subplot(4, 4, 6)
U_r = U[:, :100]
test_image = X_test[:, 50].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 100')

plt.subplot(4, 4, 7)
U_r = U[:, :150]
test_image = X_test[:, 50].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 150')

plt.subplot(4, 4, 8)
U_r = U[:, :200]
test_image = X_test[:, 50].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 200')

plt.subplot(4, 4, 9)
U_r = U[:, :300]
test_image = X_test[:, 50].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 300')

plt.subplot(4, 4, 10)
U_r = U[:, :400]
test_image = X_test[:, 50].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 400')

plt.subplot(4, 4, 11)
U_r = U[:, :500]
test_image = X_test[:, 50].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 500')

plt.subplot(4, 4, 12)
U_r = U[:, :600]
test_image = X_test[:, 50].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 600')

plt.subplot(4, 4, 13)
U_r = U[:, :700]
test_image = X_test[:, 50].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages: 700')

plt.show()

# %%
#Structural Similarity Index (SSIM)

from skimage.measure import compare_ssim

SSIM = []

plt.figure(figsize=(20, 20))

plt.subplot(4, 4, 1)
plt.imshow(X_test[:, 0].reshape(28, 28), cmap='Greys')
plt.title('Original Img')

plt.subplot(4, 4, 2)
U_r = U[:, :5]
test_image = X_test[:, 0].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
(score, diff) = compare_ssim(X_test[:, 0].reshape(28, 28) / 255, reconstructed_image.reshape(28, 28)/ 255, full=True)
SSIM.append(score)
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages:5 ' + 'SSIM: ' + str("{:.2f}".format(score)))

plt.subplot(4, 4, 3)
U_r = U[:, :10]
test_image = X_test[:, 0].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
(score, diff) = compare_ssim(X_test[:, 0].reshape(28, 28) / 255, reconstructed_image.reshape(28, 28)/ 255, full=True)
SSIM.append(score)
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages:10 ' + 'SSIM: ' + str("{:.2f}".format(score)))

plt.subplot(4, 4, 4)
U_r = U[:, :25]
test_image = X_test[:, 0].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
(score, diff) = compare_ssim(X_test[:, 0].reshape(28, 28) / 255, reconstructed_image.reshape(28, 28)/ 255, full=True)
SSIM.append(score)
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages:25 ' + 'SSIM: ' + str("{:.2f}".format(score)))

plt.subplot(4, 4, 5)
U_r = U[:, :50]
test_image = X_test[:, 0].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
(score, diff) = compare_ssim(X_test[:, 0].reshape(28, 28) / 255, reconstructed_image.reshape(28, 28)/ 255, full=True)
SSIM.append(score)
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages:50 ' + 'SSIM: ' + str("{:.2f}".format(score)))

plt.subplot(4, 4, 6)
U_r = U[:, :100]
test_image = X_test[:, 0].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
(score, diff) = compare_ssim(X_test[:, 0].reshape(28, 28) / 255, reconstructed_image.reshape(28, 28)/ 255, full=True)
SSIM.append(score)
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages:100 ' + 'SSIM: ' + str("{:.2f}".format(score)))

plt.subplot(4, 4, 7)
U_r = U[:, :150]
test_image = X_test[:, 0].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
(score, diff) = compare_ssim(X_test[:, 0].reshape(28, 28) / 255, reconstructed_image.reshape(28, 28)/ 255, full=True)
SSIM.append(score)
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages:150 ' + 'SSIM: ' + str("{:.2f}".format(score)))

plt.subplot(4, 4, 8)
U_r = U[:, :200]
test_image = X_test[:, 0].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
(score, diff) = compare_ssim(X_test[:, 0].reshape(28, 28) / 255, reconstructed_image.reshape(28, 28)/ 255, full=True)
SSIM.append(score)
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages:200 ' + 'SSIM: ' + str("{:.2f}".format(score)))

plt.subplot(4, 4, 9)
U_r = U[:, :300]
test_image = X_test[:, 0].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
(score, diff) = compare_ssim(X_test[:, 0].reshape(28, 28) / 255, reconstructed_image.reshape(28, 28)/ 255, full=True)
SSIM.append(score)
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages:300 ' + 'SSIM: ' + str("{:.2f}".format(score)))

plt.subplot(4, 4, 10)
U_r = U[:, :400]
test_image = X_test[:, 0].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
(score, diff) = compare_ssim(X_test[:, 0].reshape(28, 28) / 255, reconstructed_image.reshape(28, 28)/ 255, full=True)
SSIM.append(score)
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages:400 ' + 'SSIM: ' + str("{:.2f}".format(score)))

plt.subplot(4, 4, 11)
U_r = U[:, :500]
test_image = X_test[:, 0].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
(score, diff) = compare_ssim(X_test[:, 0].reshape(28, 28) / 255, reconstructed_image.reshape(28, 28)/ 255, full=True)
SSIM.append(score)
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages:500 ' + 'SSIM: ' + str("{:.2f}".format(score)))

plt.subplot(4, 4, 12)
U_r = U[:, :600]
test_image = X_test[:, 0].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
(score, diff) = compare_ssim(X_test[:, 0].reshape(28, 28) / 255, reconstructed_image.reshape(28, 28)/ 255, full=True)
SSIM.append(score)
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages:600 ' + 'SSIM: ' + str("{:.2f}".format(score)))

plt.subplot(4, 4, 13)
U_r = U[:, :700]
test_image = X_test[:, 0].reshape(-1, 1)
reconstructed_image = np.dot(U_r, np.dot(U_r.T, test_image))
(score, diff) = compare_ssim(X_test[:, 0].reshape(28, 28) / 255, reconstructed_image.reshape(28, 28)/ 255, full=True)
SSIM.append(score)
plt.imshow(reconstructed_image.reshape(28, 28), cmap='Greys')
plt.title('EigenImages:700 ' + 'SSIM: ' + str("{:.2f}".format(score)))

plt.show()

# %%
U.shape
# Out:
# (784, 784)

# %%
df = pd.DataFrame(U[:, :500].T)
df.shape
# Out:
# (500, 784)

# %%
df.to_csv('Eigenimages_0.csv')
